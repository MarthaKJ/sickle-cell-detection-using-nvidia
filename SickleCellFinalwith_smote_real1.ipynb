#       49.jpg
#       50.jpg
#       51.jpg
#       54.jpg
#       52.jpg
#       53.jpg
#       56.jpg
#       55.jpg
#       58.jpg
#       57.jpg
#       59.jpg
#       60.jpg
#       6.jpg
#       62.jpg
#       61.jpg
#       65.jpg
#       63.jpg
#       64.jpg
#       66.jpg
#       67.jpg
#       68.jpg
#       69.jpg
#       70.jpg
#       71.jpg
#       7.jpg
#       72.jpg
#       73.jpg
#       75.jpg
#       74.jpg
#       76.jpg
#       78.jpg
#       77.jpg
#       8.jpg
#       79.jpg
#       80.jpg
#       81.jpg
#       84.jpg
#       82.jpg
#       83.jpg
#       86.jpg
#       85.jpg
#       87.jpg
#       88.jpg
#       90.jpg
#       89.jpg
#       9.jpg
#       91.jpg
#       92.jpg
#       94.jpg
#       93.jpg
#       95.jpg
#       96.jpg
#       97.jpg
#       99.jpg
#       98.jpg

# %%
def load_data(directory, categories):
    data = []
    labels = []
    for category in categories:
        category_path = os.path.join(directory, category)
        if not os.path.isdir(category_path):
            print(f"Warning: {category} is not a directory in {directory}")
            continue

        class_num = categories.index(category)

        # Define subfolders based on the category
        if category == 'Negative':
            subfolders = ['Clear']
        elif category == 'Positive':
            subfolders = ['Unlabelled', 'Labelled']
        else:
            print(f"Warning: Unknown category {category}")
            continue

        for subfolder in subfolders:
            subfolder_path = os.path.join(category_path, subfolder)
            if not os.path.isdir(subfolder_path):
                print(f"Warning: {subfolder} not found in {category_path}")
                continue

            for img_name in os.listdir(subfolder_path):
                img_path = os.path.join(subfolder_path, img_name)
                try:
                    img_array = cv2.imread(img_path)
                    if img_array is None:
                        print(f"Error: Unable to read image {img_path}")
                        continue
                    if img_array.size == 0:
                        print(f"Error: Empty image {img_path}")
                        continue
                    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2GRAY)
                    resized_array = cv2.resize(img_array, (100, 100))
                    data.append(resized_array)
                    labels.append(class_num)
                except Exception as e:
                    print(f"Error processing image {img_path}: {str(e)}")

    if not data:
        print("No valid images found in the specified directories.")
        return np.array([]), np.array([])

    return np.array(data), np.array(labels)

# %%
# Test the function
Categories = ['Negative', 'Positive']
data, labels = load_data(Directory, Categories)
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")
# Out:
# Data shape: (991, 100, 100)
# Labels shape: (991,)

# %%
# Normalize and reshape the data
data = data / 255.0
data = data.reshape(-1, 100*100)  # Flatten the images for SMOTE

# %%
# Apply SMOTE
smote = SMOTE(random_state=42)
data_resampled, labels_resampled = smote.fit_resample(data, labels)

# %%
# Reshape back to image format
data_resampled = data_resampled.reshape(-1, 100, 100, 1)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(data_resampled, labels_resampled, test_size=0.2, random_state=42)

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Training data shape: (1350, 100, 100, 1)
# Testing data shape: (338, 100, 100, 1)

# %%
import tensorflow as tf

def create_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),

        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),

        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
# Create and summarize the model
model = create_model()
model.summary()

# Train the model
history = model.fit(X_train, y_train,
                    epochs=30,
                    batch_size=32,
                    validation_data=(X_test, y_test))

# Save the model
model.save('sickle_cell_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 98, 98, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 49, 49, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 47, 47, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 21, 21, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6400)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         409,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 465,473 (1.78 MB)
#  Trainable params: 465,473 (1.78 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.5426 - loss: 0.6923 - val_accuracy: 0.6775 - val_loss: 0.6064
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7197 - loss: 0.5619 - val_accuracy: 0.7278 - val_loss: 0.5007
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7803 - loss: 0.4672 - val_accuracy: 0.7722 - val_loss: 0.4434
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7629 - loss: 0.4605 - val_accuracy: 0.7751 - val_loss: 0.4690
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7731 - loss: 0.4625 - val_accuracy: 0.7781 - val_loss: 0.4437
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7846 - loss: 0.4414 - val_accuracy: 0.7781 - val_loss: 0.4286
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8055 - loss: 0.4145 - val_accuracy: 0.7781 - val_loss: 0.4365
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7801 - loss: 0.4276 - val_accuracy: 0.7988 - val_loss: 0.4139
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8100 - loss: 0.3931 - val_accuracy: 0.7870 - val_loss: 0.4217
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8311 - loss: 0.3568 - val_accuracy: 0.7426 - val_loss: 0.4482
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8029 - loss: 0.3969 - val_accuracy: 0.8225 - val_loss: 0.4025
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8503 - loss: 0.3522 - val_accuracy: 0.8225 - val_loss: 0.3661
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8480 - loss: 0.3491 - val_accuracy: 0.7988 - val_loss: 0.4133
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8651 - loss: 0.3393 - val_accuracy: 0.8521 - val_loss: 0.3429
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8641 - loss: 0.3137 - val_accuracy: 0.8609 - val_loss: 0.3192
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8751 - loss: 0.2968 - val_accuracy: 0.8728 - val_loss: 0.2947
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8987 - loss: 0.2540 - val_accuracy: 0.8935 - val_loss: 0.2878
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9110 - loss: 0.2304 - val_accuracy: 0.8817 - val_loss: 0.2917
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9152 - loss: 0.2232 - val_accuracy: 0.8817 - val_loss: 0.2713
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9045 - loss: 0.2206 - val_accuracy: 0.8935 - val_loss: 0.2606
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9213 - loss: 0.1943 - val_accuracy: 0.9320 - val_loss: 0.2002
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9570 - loss: 0.1325 - val_accuracy: 0.8846 - val_loss: 0.3114
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9572 - loss: 0.1383 - val_accuracy: 0.8935 - val_loss: 0.3216
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9482 - loss: 0.1379 - val_accuracy: 0.9349 - val_loss: 0.1914
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9661 - loss: 0.1042 - val_accuracy: 0.9201 - val_loss: 0.2336
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9648 - loss: 0.0959 - val_accuracy: 0.9349 - val_loss: 0.1906
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9670 - loss: 0.0987 - val_accuracy: 0.9142 - val_loss: 0.2764
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9751 - loss: 0.0678 - val_accuracy: 0.9438 - val_loss: 0.1421
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9798 - loss: 0.0758 - val_accuracy: 0.9349 - val_loss: 0.2009
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9760 - loss: 0.0609 - val_accuracy: 0.9497 - val_loss: 0.1384
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
image_path = '/content/drive/MyDrive/sickle cell uganda 2024/sickle cell uganda 2024/Negative/Clear/1.jpg'
def predict_sickle_cell(model, image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (100, 100))
    img = img / 255.0
    img = img.reshape(-1, 100, 100, 1)

    prediction = model.predict(img)

    if prediction[0][0] > 0.5:
        return "Positive", prediction[0][0]
    else:
        return "Negative", 1 - prediction[0][0]

result, confidence = predict_sickle_cell(model, image_path)
print(f"Prediction: {result}")
print(f"Confidence: {confidence:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 647ms/step
# Prediction: Negative
# Confidence: 0.97

# %%
# Importing necessary libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %%
# Flatten the images for traditional ML models
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# %%
# Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_flat)
X_test_scaled = scaler.transform(X_test_flat)

# %%
# Decision Tree
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train_scaled, y_train)
dt_pred = dt_model.predict(X_test_scaled)
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
print("Decision Tree Classification Report:")
print(classification_report(y_test, dt_pred))
# Out:
# Decision Tree Accuracy: 0.9112426035502958
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       156
#            1       0.92      0.92      0.92       182
#
#     accuracy                           0.91       338
#    macro avg       0.91      0.91      0.91       338
# weighted avg       0.91      0.91      0.91       338

# %%
# Random Forest
rf_model = RandomForestClassifier(n_estimators=30, random_state=42)
rf_model.fit(X_train_scaled, y_train)
rf_pred = rf_model.predict(X_test_scaled)
rf_accuracy = accuracy_score(y_test, rf_pred)
print("\nRandom Forest Accuracy:", rf_accuracy)
print("Random Forest Classification Report:")
print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.9674556213017751
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       156
#            1       0.98      0.96      0.97       182
#
#     accuracy                           0.97       338
#    macro avg       0.97      0.97      0.97       338
# weighted avg       0.97      0.97      0.97       338

# %%
# SVm
svm_model = SVC(kernel='rbf', random_state=30)
svm_model.fit(X_train_scaled, y_train)
svm_pred = svm_model.predict(X_test_scaled)
svm_accuracy = accuracy_score(y_test, svm_pred)
print("\nSVM Accuracy:", svm_accuracy)
print("SVM Classification Report:")
print(classification_report(y_test, svm_pred))
# Out:
# SVM Accuracy: 0.9704142011834319
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       156
#            1       0.99      0.96      0.97       182
#
#     accuracy                           0.97       338
#    macro avg       0.97      0.97      0.97       338
# weighted avg       0.97      0.97      0.97       338

# %%
# Compare with CNN model
cnn_pred = (model.predict(X_test) > 0.5).astype(int)
cnn_accuracy = accuracy_score(y_test, cnn_pred)
print("\nCNN Model Accuracy:", cnn_accuracy)
print("CNN Model Classification Report:")
print(classification_report(y_test, cnn_pred))
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
#
# CNN Model Accuracy: 0.9497041420118343
# CNN Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       156
#            1       0.95      0.96      0.95       182
#
#     accuracy                           0.95       338
#    macro avg       0.95      0.95      0.95       338
# weighted avg       0.95      0.95      0.95       338

# %%
# TensorFlow CNN model (your existing model)
tf_pred = (model.predict(X_train) > 0.5).astype(int)
tf_accuracy = accuracy_score(y_train, tf_pred)
print("\nTensorFlow CNN Model Accuracy:", tf_accuracy)
print("TensorFlow CNN Model Classification Report:")
print(classification_report(y_train, tf_pred))
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
#
# TensorFlow CNN Model Accuracy: 0.9918518518518519
# TensorFlow CNN Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       688
#            1       0.99      1.00      0.99       662
#
#     accuracy                           0.99      1350
#    macro avg       0.99      0.99      0.99      1350
# weighted avg       0.99      0.99      0.99      1350

# %%
# Visualize results
import matplotlib.pyplot as plt

models = ['Decision Tree', 'Random Forest', 'SVM', 'TensorFlow CNN']
accuracies = [dt_accuracy, rf_accuracy, svm_accuracy, tf_accuracy]

plt.figure(figsize=(10, 6))
plt.bar(models, accuracies)
plt.title('Model Comparison (Training Accuracy)')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
for i, v in enumerate(accuracies):
    plt.text(i, v + 0.01, f'{v:.2f}', ha='center')
plt.show()
